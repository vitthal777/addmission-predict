# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

# %%
df=pd.read_excel('cleanedaddmision.xlsx')
df
# Out:
#      Unnamed: 0  GRE Score  TOEFL Score  University Rating  CGPA  Research  \
# 0             0        337          118                  4  9.65         1
# 1             1        324          107                  4  8.87         1
# 2             2        316          104                  3  8.00         1
# 3             3        322          110                  3  8.67         1
# 4             4        314          103                  2  8.21         0
# ..          ...        ...          ...                ...   ...       ...
# 495         495        332          108                  5  9.02         1
# 496         496        337          117                  5  9.87         1
# 497         497        330          120                  5  9.56         1
# 498         498        312          103                  4  8.43         0
# 499         499        327          113                  4  9.04         0
#
#      Chance of Admit
# 0               0.92
# 1               0.76
# ...

# %%
x=df.drop('Chance of Admit',axis=1)
y=df['Chance of Admit']
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=9)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_convert=PolynomialFeatures(degree=1,include_bias=False)

xtrain_poly=pd.DataFrame(poly_convert.fit_transform(xtrain))
xtest_poly=pd.DataFrame(poly_convert.fit_transform(xtest))


from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(xtrain_poly,ytrain)

#print('coefficient:',model.coef_)
#print("intercept:",model.intercept_)


ypred_train=model.predict(xtrain_poly)

from sklearn.metrics import r2_score
print("train r2:",r2_score(ytrain,ypred_train))

from sklearn.model_selection import cross_val_score
print("cross validation score:",cross_val_score(model,xtrain_poly,ytrain,cv=5).mean())


ypred_test=model.predict(xtest_poly)
print("test r2:",r2_score(ytest,ypred_test))
# Out:
# train r2: 0.8245488818129852
# cross validation score: 0.8157952574826283
# test r2: 0.8115129853895002

# %%
ypred_train=model.predict(xtrain_poly)

from sklearn.metrics import r2_score
print("train r2:",r2_score(ytrain,ypred_train))

from sklearn.model_selection import cross_val_score
print("cross validation score:",cross_val_score(model,xtrain_poly,ytrain,cv=5).mean())


ypred_test=model.predict(xtest_poly)
print("test r2:",r2_score(ytest,ypred_test))
# Out:
# train r2: 0.8245488818129852
# cross validation score: 0.8157952574826283
# test r2: 0.8115129853895002

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 model.predict([[25,66,3,55]])
#
# File ~\anaconda3\New folder\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File ~\anaconda3\New folder\Lib\site-packages\sklearn\linear_model\_base.py:285, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
#     283     check_is_fitted(self)
# --> 285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#     287     if coef_.ndim == 1:
#
# ...
